# %%
import nibabel as nib
import imageio
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import torch.optim as optim
import torch.nn as nn
from tqdm.notebook import tqdm
from PIL import Image
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset
import torch
import segmentation_models_pytorch as smp
import albumentations as albu
from PIL import Image
import re
import subprocess
import pre_proc_functions as proc
from natsort import natsorted
import pandas as pd
import shutil
import inference_flex_functions as inf

# %%
#####DEFINE ALL VARIABLES HERE####
#input_directory
images_dir = 'PigNii_skullstrip-main/PigNii_skullstrip-main/example_imgs'
#Study Name
study_name = 'res'
metrics_out = 'res'
truth_folder = 'masks_swapped_val' #If you want to calculate metrics
#Checkpoint Path
model_sag_path = 'PigNii_skullstrip-main/PigNii_skullstrip-main/model_checkpoints/Unet_efficientnet-b3_sag.pth'
model_cor_path = 'PigNii_skullstrip-main/PigNii_skullstrip-main/model_checkpoints/Unet_efficientnet-b3_cor.pth'
model_ax_path = 'PigNii_skullstrip-main/PigNii_skullstrip-main/model_checkpoints/Unet_efficientnet-b3_ax.pth'
#Encoder Type
encoder_type = "efficientnet-b3"
#Image Dimensions
sag_dim = [288,288]
cor_dim = [256,288]
ax_dim = [256,288]

# %%
images_output_dir = study_name + "/raw_png"
raw_png_output = study_name + '/raw_png_output'
raw_npy_output = study_name + '/raw_npy_output'
volumn_out = study_name + "/volumn_out"
prob_out = study_name + "/prob_out"
final_out = study_name + '/final_out'

if not os.path.exists(images_output_dir):
    os.makedirs(images_output_dir)
    os.makedirs(os.path.join(images_output_dir,'sag'))
    os.makedirs(os.path.join(images_output_dir,'ax'))
    os.makedirs(os.path.join(images_output_dir,'cor'))
raw_png_sag = os.path.join(images_output_dir,'sag')
raw_png_ax = os.path.join(images_output_dir,'ax')
raw_png_cor = os.path.join(images_output_dir,'cor')

if not os.path.exists(raw_png_output):
    os.makedirs(raw_png_output)
    os.makedirs(os.path.join(raw_png_output,'sag'))
    os.makedirs(os.path.join(raw_png_output,'ax'))
    os.makedirs(os.path.join(raw_png_output,'cor'))

raw_png_sag_output = os.path.join(raw_png_output,'sag')
raw_png_ax_output = os.path.join(raw_png_output,'ax')
raw_png_cor_output = os.path.join(raw_png_output,'cor')

if not os.path.exists(raw_npy_output):
    os.makedirs(raw_npy_output)
    os.makedirs(os.path.join(raw_npy_output,'sag'))
    os.makedirs(os.path.join(raw_npy_output,'ax'))
    os.makedirs(os.path.join(raw_npy_output,'cor'))

raw_npy_sag_output = os.path.join(raw_npy_output,'sag')
raw_npy_ax_output = os.path.join(raw_npy_output,'ax')
raw_npy_cor_output = os.path.join(raw_npy_output,'cor')

if not os.path.exists(volumn_out):
    os.makedirs(volumn_out)
    os.makedirs(os.path.join(volumn_out,'sag'))
    os.makedirs(os.path.join(volumn_out,'ax'))
    os.makedirs(os.path.join(volumn_out,'cor'))

volumn_out_sag = os.path.join(volumn_out,'sag')
volumn_out_ax = os.path.join(volumn_out,'ax')
volumn_out_cor = os.path.join(volumn_out,'cor')

if not os.path.exists(prob_out):
    os.makedirs(prob_out)
    os.makedirs(os.path.join(prob_out,'sag'))
    os.makedirs(os.path.join(prob_out,'ax'))
    os.makedirs(os.path.join(prob_out,'cor'))

prob_out_sag = os.path.join(prob_out,'sag')
prob_out_ax = os.path.join(prob_out,'ax')
prob_out_cor = os.path.join(prob_out,'cor')

proc.proc_img_masks(img_dir=images_dir, out_dir=images_output_dir,img_fixed = "_mc_restore", mask_fixed = '-mask')

files_list_sag = inf.get_files_starting_with(raw_png_sag, "Pig")
print(sorted(files_list_sag))
files_list_sag = sorted(files_list_sag)

files_list_ax = inf.get_files_starting_with(raw_png_ax, "Pig")
print(sorted(files_list_ax))
files_list_ax = sorted(files_list_ax)

files_list_cor = inf.get_files_starting_with(raw_png_cor, "Pig")
print(sorted(files_list_cor))
files_list_cor = sorted(files_list_cor)

model_sag = torch.load(model_sag_path)
model_cor = torch.load(model_cor_path)
model_ax = torch.load(model_ax_path)
preprocessing_fn = smp.encoders.get_preprocessing_fn(encoder_type, "imagenet")
sag_dataset = inf.Dataset(
    images_dir = raw_png_sag, 
    preprocessing=inf.get_preprocessing(preprocessing_fn),
    classes=['brain'],
)

cor_dataset = inf.Dataset(
    images_dir = raw_png_cor, 
    preprocessing=inf.get_preprocessing(preprocessing_fn),
    classes=['brain'],
)

ax_dataset = inf.Dataset(
    images_dir = raw_png_ax, 
    preprocessing=inf.get_preprocessing(preprocessing_fn),
    classes=['brain'],
)

for i in range(len(files_list_sag)):
    torch.cuda.empty_cache()
    filename = files_list_sag[i]
    x2= inf.get_data_from_filename(filename, sag_dataset)
    x2 = torch.tensor(x2).unsqueeze(0).repeat(32,1,1,1)
    model_sag = model_sag.to('cuda')
    with torch.no_grad():
        model_sag.eval()
        output = model_sag(x2.float().to('cuda'))
    output = output[0].squeeze()
    mask = ((output / output.max()) > 0.05).float().to('cpu').numpy()
    probability = ((output - output.min()) / (output.max() - output.min())).float().to('cpu').numpy()
    print("slice num : ", i)
    base_name, ext = os.path.splitext(files_list_sag[i])
    b_base = os.path.basename(base_name)
    prob_path = os.path.join(prob_out_sag, f"{b_base}.npy")
    mask_path = os.path.join(raw_npy_sag_output, f"{b_base}.npy")
    np.save(prob_path, probability)
    np.save(mask_path, mask)
    print(f'this is base_name: {files_list_sag[i]}')
    inf.display([x2[0].permute([1,2,0]).squeeze(), x2.squeeze(), mask], epoch=os.path.basename(base_name), save_path= None, is_inference=True, inference_path=(raw_png_output+'/sag'))

for i in range(len(files_list_cor)):
    torch.cuda.empty_cache()
    filename = files_list_cor[i]
    x2= inf.get_data_from_filename(filename, cor_dataset)
    x2 = torch.tensor(x2).unsqueeze(0).repeat(32,1,1,1)
    model_cor = model_cor.to('cuda')
    with torch.no_grad():
        model_cor.eval()
        output = model_cor(x2.float().to('cuda'))
    output = output[0].squeeze()
    mask = ((output / output.max()) > 0.05).float().to('cpu').numpy()
    probability = ((output - output.min()) / (output.max() - output.min())).float().to('cpu').numpy()
    print("slice num : ", i)
    base_name, ext = os.path.splitext(files_list_cor[i])
    b_base = os.path.basename(base_name)
    prob_path = os.path.join(prob_out_cor, f"{b_base}.npy")
    mask_path = os.path.join(raw_npy_cor_output, f"{b_base}.npy")
    np.save(prob_path, probability)
    np.save(mask_path, mask)
    print(f'this is base_name: {files_list_cor[i]}')
    inf.display([x2[0].permute([1,2,0]).squeeze(), x2.squeeze(), mask], epoch=os.path.basename(base_name), save_path= None, is_inference=True, inference_path=(raw_png_output+'/cor'))

for i in range(len(files_list_ax)):
    torch.cuda.empty_cache()
    filename = files_list_ax[i]
    x2= inf.get_data_from_filename(filename, ax_dataset)
    x2 = torch.tensor(x2).unsqueeze(0).repeat(32,1,1,1)
    model_ax = model_ax.to('cuda')
    with torch.no_grad():
        model_ax.eval()
        output = model_ax(x2.float().to('cuda'))
    output = output[0].squeeze()
    mask = ((output / output.max()) > 0.05).float().to('cpu').numpy()
    probability = ((output - output.min()) / (output.max() - output.min())).float().to('cpu').numpy()
    print("slice num : ", i)
    base_name, ext = os.path.splitext(files_list_ax[i])
    b_base = os.path.basename(base_name)
    prob_path = os.path.join(prob_out_ax, f"{b_base}.npy")
    mask_path = os.path.join(raw_npy_ax_output, f"{b_base}.npy")
    np.save(prob_path, probability)
    np.save(mask_path, mask)
    print(f'this is base_name: {files_list_ax[i]}')
    inf.display([x2[0].permute([1,2,0]).squeeze(), x2.squeeze(), mask], epoch=os.path.basename(base_name), save_path= None, is_inference=True, inference_path=(raw_png_output+'/ax'))


input_dir_sag = f'{study_name}/raw_npy_output/sag'
input_dir_cor = f'{study_name}/raw_npy_output/cor'
input_dir_ax = f'{study_name}/raw_npy_output/ax'
output_dir_sag = volumn_out + '/sag'
output_dir_cor = volumn_out + '/cor'
output_dir_ax = volumn_out + '/ax'
source_dir = images_dir
inf.stack_slices_and_save_nifti(input_dir_sag, output_dir_sag, source_dir, 2)
inf.stack_slices_and_save_nifti(input_dir_cor, output_dir_cor, source_dir, 1)
inf.stack_slices_and_save_nifti(input_dir_ax, output_dir_ax, source_dir, 0)

inf.run_fslmaths(output_dir_sag, output_dir_cor, output_dir_ax, final_out)
###Uncomment if calculating metrics####
#outputcsv_dice = metrics_out + f'dice.csv' 
#outputcsv_iou = metrics_out + f'iou.csv' 
#inf.calc3dDice(final_out,volumn_out, truth_folder, outputcsv_dice)
#inf.calc3dIOU(final_out,volumn_out, truth_folder, outputcsv_iou)
# Out:
# Pig_536
# Processed res/raw_png/./sag/Pig_536_slice000.png
# Processed res/raw_png/./sag/Pig_536_slice001.png
# Processed res/raw_png/./sag/Pig_536_slice002.png
# Processed res/raw_png/./sag/Pig_536_slice003.png
# Processed res/raw_png/./sag/Pig_536_slice004.png
# Processed res/raw_png/./sag/Pig_536_slice005.png
# Processed res/raw_png/./sag/Pig_536_slice006.png
# Processed res/raw_png/./sag/Pig_536_slice007.png
# Processed res/raw_png/./sag/Pig_536_slice008.png
# Processed res/raw_png/./cor/Pig_537_slice157.png
# Processed res/raw_png/./cor/Pig_537_slice158.png
# Processed res/raw_png/./cor/Pig_537_slice159.png
# Processed res/raw_png/./cor/Pig_537_slice160.png
# Processed res/raw_png/./cor/Pig_537_slice161.png
# Processed res/raw_png/./cor/Pig_537_slice162.png
# Processed res/raw_png/./cor/Pig_537_slice163.png
# Processed res/raw_png/./cor/Pig_537_slice164.png
# Processed res/raw_png/./cor/Pig_537_slice165.png
# Processed res/raw_png/./cor/Pig_537_slice166.png
# Processed res/raw_png/./cor/Pig_537_slice167.png
# Processed res/raw_png/./cor/Pig_537_slice168.png
# Processed res/raw_png/./cor/Pig_537_slice169.png
# Processed res/raw_png/./cor/Pig_537_slice170.png
# Processed res/raw_png/./cor/Pig_537_slice171.png
# Processed res/raw_png/./cor/Pig_537_slice172.png
# Processed res/raw_png/./cor/Pig_537_slice173.png
# Processed res/raw_png/./cor/Pig_537_slice174.png
# Processed res/raw_png/./cor/Pig_537_slice175.png
# Processed res/raw_png/./cor/Pig_537_slice176.png
# Processed res/raw_png/./cor/Pig_537_slice177.png
# ...
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice206.png
# (288, 256)
# slice num :  495
# this is base_name: res/raw_png/ax/Pig_537_slice207.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice207.png
# (288, 256)
# slice num :  496
# this is base_name: res/raw_png/ax/Pig_537_slice208.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice208.png
# (288, 256)
# slice num :  497
# this is base_name: res/raw_png/ax/Pig_537_slice209.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice209.png
# (288, 256)
# slice num :  498
# this is base_name: res/raw_png/ax/Pig_537_slice210.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice210.png
# (288, 256)
# slice num :  499
# this is base_name: res/raw_png/ax/Pig_537_slice211.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice211.png
# (288, 256)
# slice num :  500
# this is base_name: res/raw_png/ax/Pig_537_slice212.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice212.png
# (288, 256)
# slice num :  501
# this is base_name: res/raw_png/ax/Pig_537_slice213.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice213.png
# (288, 256)
# slice num :  502
# this is base_name: res/raw_png/ax/Pig_537_slice214.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice214.png
# (288, 256)
# slice num :  503
# this is base_name: res/raw_png/ax/Pig_537_slice215.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice215.png
# (288, 256)
# slice num :  504
# this is base_name: res/raw_png/ax/Pig_537_slice216.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice216.png
# (288, 256)
# slice num :  505
# this is base_name: res/raw_png/ax/Pig_537_slice217.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice217.png
# (288, 256)
# slice num :  506
# this is base_name: res/raw_png/ax/Pig_537_slice218.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice218.png
# (288, 256)
# slice num :  507
# this is base_name: res/raw_png/ax/Pig_537_slice219.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice219.png
# (288, 256)
# slice num :  508
# this is base_name: res/raw_png/ax/Pig_537_slice220.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice220.png
# (288, 256)
# slice num :  509
# this is base_name: res/raw_png/ax/Pig_537_slice221.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice221.png
# (288, 256)
# slice num :  510
# this is base_name: res/raw_png/ax/Pig_537_slice222.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice222.png
# (288, 256)
# slice num :  511
# this is base_name: res/raw_png/ax/Pig_537_slice223.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice223.png
# (288, 256)
# slice num :  512
# this is base_name: res/raw_png/ax/Pig_537_slice224.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice224.png
# (288, 256)
# slice num :  513
# this is base_name: res/raw_png/ax/Pig_537_slice225.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice225.png
# (288, 256)
# slice num :  514
# this is base_name: res/raw_png/ax/Pig_537_slice226.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice226.png
# (288, 256)
# slice num :  515
# this is base_name: res/raw_png/ax/Pig_537_slice227.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice227.png
# (288, 256)
# slice num :  516
# this is base_name: res/raw_png/ax/Pig_537_slice228.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice228.png
# (288, 256)
# slice num :  517
# this is base_name: res/raw_png/ax/Pig_537_slice229.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice229.png
# (288, 256)
# slice num :  518
# this is base_name: res/raw_png/ax/Pig_537_slice230.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice230.png
# (288, 256)
# slice num :  519
# this is base_name: res/raw_png/ax/Pig_537_slice231.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice231.png
# (288, 256)
# slice num :  520
# this is base_name: res/raw_png/ax/Pig_537_slice232.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice232.png
# (288, 256)
# slice num :  521
# this is base_name: res/raw_png/ax/Pig_537_slice233.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice233.png
# (288, 256)
# slice num :  522
# this is base_name: res/raw_png/ax/Pig_537_slice234.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice234.png
# (288, 256)
# slice num :  523
# this is base_name: res/raw_png/ax/Pig_537_slice235.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice235.png
# (288, 256)
# slice num :  524
# this is base_name: res/raw_png/ax/Pig_537_slice236.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice236.png
# (288, 256)
# slice num :  525
# this is base_name: res/raw_png/ax/Pig_537_slice237.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice237.png
# (288, 256)
# slice num :  526
# this is base_name: res/raw_png/ax/Pig_537_slice238.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice238.png
# (288, 256)
# slice num :  527
# this is base_name: res/raw_png/ax/Pig_537_slice239.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice239.png
# (288, 256)
# slice num :  528
# this is base_name: res/raw_png/ax/Pig_537_slice240.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice240.png
# (288, 256)
# slice num :  529
# this is base_name: res/raw_png/ax/Pig_537_slice241.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice241.png
# (288, 256)
# slice num :  530
# this is base_name: res/raw_png/ax/Pig_537_slice242.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice242.png
# (288, 256)
# slice num :  531
# this is base_name: res/raw_png/ax/Pig_537_slice243.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice243.png
# (288, 256)
# slice num :  532
# this is base_name: res/raw_png/ax/Pig_537_slice244.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice244.png
# (288, 256)
# slice num :  533
# this is base_name: res/raw_png/ax/Pig_537_slice245.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice245.png
# (288, 256)
# slice num :  534
# this is base_name: res/raw_png/ax/Pig_537_slice246.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice246.png
# (288, 256)
# slice num :  535
# this is base_name: res/raw_png/ax/Pig_537_slice247.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice247.png
# (288, 256)
# slice num :  536
# this is base_name: res/raw_png/ax/Pig_537_slice248.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice248.png
# (288, 256)
# slice num :  537
# this is base_name: res/raw_png/ax/Pig_537_slice249.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice249.png
# (288, 256)
# slice num :  538
# this is base_name: res/raw_png/ax/Pig_537_slice250.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice250.png
# (288, 256)
# slice num :  539
# this is base_name: res/raw_png/ax/Pig_537_slice251.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice251.png
# (288, 256)
# slice num :  540
# this is base_name: res/raw_png/ax/Pig_537_slice252.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice252.png
# (288, 256)
# slice num :  541
# this is base_name: res/raw_png/ax/Pig_537_slice253.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice253.png
# (288, 256)
# slice num :  542
# this is base_name: res/raw_png/ax/Pig_537_slice254.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice254.png
# (288, 256)
# slice num :  543
# this is base_name: res/raw_png/ax/Pig_537_slice255.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice255.png
# (288, 256)
# slice num :  544
# this is base_name: res/raw_png/ax/Pig_537_slice256.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice256.png
# (288, 256)
# slice num :  545
# this is base_name: res/raw_png/ax/Pig_537_slice257.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice257.png
# (288, 256)
# slice num :  546
# this is base_name: res/raw_png/ax/Pig_537_slice258.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice258.png
# (288, 256)
# slice num :  547
# this is base_name: res/raw_png/ax/Pig_537_slice259.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice259.png
# (288, 256)
# slice num :  548
# this is base_name: res/raw_png/ax/Pig_537_slice260.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice260.png
# (288, 256)
# slice num :  549
# this is base_name: res/raw_png/ax/Pig_537_slice261.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice261.png
# (288, 256)
# slice num :  550
# this is base_name: res/raw_png/ax/Pig_537_slice262.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice262.png
# (288, 256)
# slice num :  551
# this is base_name: res/raw_png/ax/Pig_537_slice263.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice263.png
# (288, 256)
# slice num :  552
# this is base_name: res/raw_png/ax/Pig_537_slice264.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice264.png
# (288, 256)
# slice num :  553
# this is base_name: res/raw_png/ax/Pig_537_slice265.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice265.png
# (288, 256)
# slice num :  554
# this is base_name: res/raw_png/ax/Pig_537_slice266.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice266.png
# (288, 256)
# slice num :  555
# this is base_name: res/raw_png/ax/Pig_537_slice267.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice267.png
# (288, 256)
# slice num :  556
# this is base_name: res/raw_png/ax/Pig_537_slice268.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice268.png
# (288, 256)
# slice num :  557
# this is base_name: res/raw_png/ax/Pig_537_slice269.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice269.png
# (288, 256)
# slice num :  558
# this is base_name: res/raw_png/ax/Pig_537_slice270.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice270.png
# (288, 256)
# slice num :  559
# this is base_name: res/raw_png/ax/Pig_537_slice271.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice271.png
# (288, 256)
# slice num :  560
# this is base_name: res/raw_png/ax/Pig_537_slice272.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice272.png
# (288, 256)
# slice num :  561
# this is base_name: res/raw_png/ax/Pig_537_slice273.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice273.png
# (288, 256)
# slice num :  562
# this is base_name: res/raw_png/ax/Pig_537_slice274.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice274.png
# (288, 256)
# slice num :  563
# this is base_name: res/raw_png/ax/Pig_537_slice275.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice275.png
# (288, 256)
# slice num :  564
# this is base_name: res/raw_png/ax/Pig_537_slice276.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice276.png
# (288, 256)
# slice num :  565
# this is base_name: res/raw_png/ax/Pig_537_slice277.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice277.png
# (288, 256)
# slice num :  566
# this is base_name: res/raw_png/ax/Pig_537_slice278.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice278.png
# (288, 256)
# slice num :  567
# this is base_name: res/raw_png/ax/Pig_537_slice279.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice279.png
# (288, 256)
# slice num :  568
# this is base_name: res/raw_png/ax/Pig_537_slice280.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice280.png
# (288, 256)
# slice num :  569
# this is base_name: res/raw_png/ax/Pig_537_slice281.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice281.png
# (288, 256)
# slice num :  570
# this is base_name: res/raw_png/ax/Pig_537_slice282.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice282.png
# (288, 256)
# slice num :  571
# this is base_name: res/raw_png/ax/Pig_537_slice283.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice283.png
# (288, 256)
# slice num :  572
# this is base_name: res/raw_png/ax/Pig_537_slice284.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice284.png
# (288, 256)
# slice num :  573
# this is base_name: res/raw_png/ax/Pig_537_slice285.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice285.png
# (288, 256)
# slice num :  574
# this is base_name: res/raw_png/ax/Pig_537_slice286.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice286.png
# (288, 256)
# slice num :  575
# this is base_name: res/raw_png/ax/Pig_537_slice287.png
# converting.........................................
# writing to res/raw_png_output/ax/Pig_537_slice287.png
# (288, 256)
# Saved 3D NIfTI volume for Pig 536 to res/volumn_out/sag/Pig_536_mask.nii.gz
# Saved 3D NIfTI volume for Pig 537 to res/volumn_out/sag/Pig_537_mask.nii.gz
# Saved 3D NIfTI volume for Pig 536 to res/volumn_out/cor/Pig_536_mask.nii.gz
# Saved 3D NIfTI volume for Pig 537 to res/volumn_out/cor/Pig_537_mask.nii.gz
# Saved 3D NIfTI volume for Pig 536 to res/volumn_out/ax/Pig_536_mask.nii.gz
# Saved 3D NIfTI volume for Pig 537 to res/volumn_out/ax/Pig_537_mask.nii.gz
# Processed and saved: res/final_out/Pig_536_mask.nii.gz
# Processed and saved: res/final_out/Pig_537_mask.nii.gz
